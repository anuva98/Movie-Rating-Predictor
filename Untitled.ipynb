# %%
import pandas as pd
df = pd.read_csv('tmdb_5000_movies.csv')
print(df.head(10))
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
print(df)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.columns
df['production_companies'][1]
# Out:
# '[{"name": "Walt Disney Pictures", "id": 2}, {"name": "Jerry Bruckheimer Films", "id": 130}, {"name": "Second Mate Productions", "id": 19936}]'

# %%
selected_columns = ['id', 'title', 'revenue']
selected_df = df[selected_columns]
print(selected_df.head())
# Out:
#        id                                     title     revenue
# 0   19995                                    Avatar  2787965087
# 1     285  Pirates of the Caribbean: At World's End   961000000
# 2  206647                                   Spectre   880674609
# 3   49026                     The Dark Knight Rises  1084939099
# 4   49529                               John Carter   284139100

# %%
df_credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
# print(df_credits.head(10))
# df_credits['crew'][3]
df_credits[df_credits['movie_id'] == 285]
# Out:
#    movie_id                                     title  \
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
df_credits.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
df.rename(columns={'id': 'movie_id'}, inplace=True)
merged_df = pd.merge(df, df_credits, on=['movie_id', 'title'])

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'movie_id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
merged_df = pd.merge(df, df_credits, on='movie_id')

# %%
merged_df.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  movie_id  \
# 0                        http://www.avatarmovie.com/     19995
# 1       http://disney.go.com/disneypictures/pirates/       285
# 2        http://www.sonypictures.com/movies/spectre/    206647
# ...

# %%
selected_columns_merged = ['movie_id', 'title_x', 'cast']
selected_df_merged = merged_df[selected_columns_merged]
print(selected_df_merged.head())
# Out:
#    movie_id                                   title_x  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...

# %%
print(selected_df_merged)
# Out:
#       movie_id                                   title_x  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
display(selected_df_merged)
# Out:
#       movie_id                                   title_x  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
result_df = df[merged_df['title_x'] != merged_df['original_title']]

# Display the result DataFrame
print(result_df)
# Out:
#          budget                                             genres  \
# 97     15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 215   130000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 235    97250400  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 317    94000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 474           0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# ...         ...                                                ...
# 4699          0                      [{"id": 18, "name": "Drama"}]
# 4719     120000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4751          0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4790          0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
#
#                                                homepage  movie_id  \
# 97                                                  NaN    315011
# ...

# %%
# english_movies_df.columns
# english_movies_df.sort_values('movie_id', inplace=True)
merged_df.set_index('movie_id', inplace=True)

# %%
# # Display the DataFrame with 'id' as the index
# display(english_movies_df)

# # Sort the DataFrame by the 'id' column
# english_movies_df.sort_values('movie_id', inplace=True)

# # Reset the index to be in increasing order
# english_movies_df.reset_index(drop=True, inplace=True)
# english_movies_df.set_index('movie_id', inplace=True)

merged_df.at[285, 'cast']
# Out:
# '[{"cast_id": 4, "character": "Captain Jack Sparrow", "credit_id": "52fe4232c3a36847f800b50d", "gender": 2, "id": 85, "name": "Johnny Depp", "order": 0}, {"cast_id": 5, "character": "Will Turner", "credit_id": "52fe4232c3a36847f800b511", "gender": 2, "id": 114, "name": "Orlando Bloom", "order": 1}, {"cast_id": 6, "character": "Elizabeth Swann", "credit_id": "52fe4232c3a36847f800b515", "gender": 1, "id": 116, "name": "Keira Knightley", "order": 2}, {"cast_id": 12, "character": "William \\"Bootstrap Bill\\" Turner", "credit_id": "52fe4232c3a36847f800b52d", "gender": 2, "id": 1640, "name": "Stellan Skarsg\\u00e5rd", "order": 3}, {"cast_id": 10, "character": "Captain Sao Feng", "credit_id": "52fe4232c3a36847f800b525", "gender": 2, "id": 1619, "name": "Chow Yun-fat", "order": 4}, {"cast_id": 9, "character": "Captain Davy Jones", "credit_id": "52fe4232c3a36847f800b521", "gender": 2, "id": 2440, "name": "Bill Nighy", "order": 5}, {"cast_id": 7, "character": "Captain Hector Barbossa", "credi
# ...

# %%
display(english_movies_df.columns)
display(english_movies_df.head())
# Out:
# Index(['budget', 'genres', 'keywords', 'original_language', 'overview',
#        'popularity', 'production_companies', 'release_date', 'revenue',
#        'runtime', 'tagline', 'title', 'vote_average', 'vote_count', 'director',
#        'Actor1', 'Actor2', 'Actor3', 'Actor4', 'Actor5', 'Actor1_popularity',
#        'Actor2_popularity', 'Actor3_popularity', 'Actor4_popularity',
#        'Actor5_popularity', 'director_popularity',
#        'production_companies_populairty', 'War', 'Thriller', 'Action',
#        'Horror', 'Comedy', 'Mystery', 'Fantasy', 'History', 'Crime', 'Romance',
#        'Family', 'Drama', 'Adventure', 'Music', 'Documentary', 'Western',
#        'Animation', 'TV Movie', 'Science Fiction', 'Foreign', 'tags'],
#       dtype='object')
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# ...

# %%
# Data preprocessing: merged columns (renamed id to movie_id for merge) , dropped some duplicate columns: title_y, original_title
# drop irrelevant columns: homepage, production_countries, spoken_languages, status, (can't drop crew because say its a cristopher nolan movie, it'll have a lot of affect on rating)
merged_df.drop(['homepage', 'production_countries', 'spoken_languages', 'status', 'title_y', 'original_title'], axis=1, inplace=True)
# filtered on language: choosing only english (already done here but after clean up will happen at this step)
english_movies_df = merged_df[merged_df['original_language'] == 'en']
display(english_movies_df)
# Out:
#              budget                                             genres  \
# movie_id
# 19995     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285       300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647    245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...             ...                                                ...
# 67238             0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 72766          9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 231617            0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 126186            0                                                 []
# 25975             0                [{"id": 99, "name": "Documentary"}]
#
#                                                    keywords original_language  \
# movie_id
# ...

# %%
english_movies_df.head()
# Out:
#              budget                                             genres  \
# movie_id
# 19995     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285       300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647    245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                    keywords original_language  \
# movie_id
# 19995     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285       [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 206647    [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 49026     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 49529     [{"id": 818, "name": "based on novel"}, {"id":...                en
#
# ...

# %%
english_movies_df.at[285, 'keywords']
# Out:
# '[{"id": 270, "name": "ocean"}, {"id": 726, "name": "drug abuse"}, {"id": 911, "name": "exotic island"}, {"id": 1319, "name": "east india trading company"}, {"id": 2038, "name": "love of one\'s life"}, {"id": 2052, "name": "traitor"}, {"id": 2580, "name": "shipwreck"}, {"id": 2660, "name": "strong woman"}, {"id": 3799, "name": "ship"}, {"id": 5740, "name": "alliance"}, {"id": 5941, "name": "calypso"}, {"id": 6155, "name": "afterlife"}, {"id": 6211, "name": "fighter"}, {"id": 12988, "name": "pirate"}, {"id": 157186, "name": "swashbuckler"}, {"id": 179430, "name": "aftercreditsstinger"}]'

# %%
english_movies_df.at[285, 'overview']
# Out:
# 'Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.'

# %%
import json
def convert_json_to_name_tag(json_str):
    tags = []
    # Parse the JSON-formatted string into a list of dictionaries
    try:
        json_obj = json.loads(json_str)
    except json.JSONDecodeError:
        print("Error decoding JSON string.")
        return []
    
    for obj in json_obj:
        name = obj["name"]
        tags.append(name)
    return tags

# %%
json_obj = english_movies_df.at[285, 'keywords']
print(convert_json_to_name_tag(json_obj))
# Out:
# ['ocean', 'drug abuse', 'exotic island', 'east india trading company', "love of one's life", 'traitor', 'shipwreck', 'strong woman', 'ship', 'alliance', 'calypso', 'afterlife', 'fighter', 'pirate', 'swashbuckler', 'aftercreditsstinger']

# %%
json_obj = english_movies_df.at[285, 'cast']
print(convert_json_to_name_tag(json_obj))
# Out:
# ['Johnny Depp', 'Orlando Bloom', 'Keira Knightley', 'Stellan Skarsgård', 'Chow Yun-fat', 'Bill Nighy', 'Geoffrey Rush', 'Jack Davenport', 'Kevin McNally', 'Tom Hollander', 'Naomie Harris', 'Jonathan Pryce', 'Keith Richards', 'Lee Arenberg', 'Mackenzie Crook', 'Greg Ellis', 'David Bailie', 'Martin Klebba', 'David Schofield', 'Lauren Maher', 'Vanessa Branch', 'Angus Barnett', 'Giles New', 'Reggie Lee', 'Dominic Scott Kay', 'Takayo Fischer', 'David Meunier', 'Ho-Kwan Tse', 'Andy Beckwith', 'Peter Donald Badalamenti II', 'Christopher S. Capp', 'Keith Richards', 'Hakeem Kae-Kazim', 'Ghassan Massoud']

# %%
json_obj = english_movies_df.at[285, 'genres']
print(convert_json_to_name_tag(json_obj))
# Out:
# ['Adventure', 'Fantasy', 'Action']

# %%
english_movies_df['genres']=english_movies_df['genres'].apply(convert_json_to_name_tag)
# Out:
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/2607563268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df['genres']=english_movies_df['genres'].apply(convert_json_to_name_tag)

# %%
english_movies_df['cast']=english_movies_df['cast'].apply(convert_json_to_name_tag)
# english_movies_df['crew']=english_movies_df['crew'].apply(convert_json_to_name_tag)
english_movies_df['keywords']=english_movies_df['keywords'].apply(convert_json_to_name_tag)
# Out:
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/1443744394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df['cast']=english_movies_df['cast'].apply(convert_json_to_name_tag)
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/1443744394.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df['keywords']=english_movies_df['keywords'].apply(convert_json_to_name_tag)

# %%
english_movies_df['production_companies']=english_movies_df['production_companies'].apply(convert_json_to_name_tag)
# Out:
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/2739161411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df['production_companies']=english_movies_df['production_companies'].apply(convert_json_to_name_tag)

# %%
english_movies_df.head()
# Out:
#              budget                                         genres  \
# movie_id
# 19995     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285       300000000                   [Adventure, Fantasy, Action]
# 206647    245000000                     [Action, Adventure, Crime]
# 49026     250000000               [Action, Crime, Drama, Thriller]
# 49529     260000000           [Action, Adventure, Science Fiction]
#
#                                                    keywords original_language  \
# movie_id
# 19995     [culture clash, future, space war, space colon...                en
# 285       [ocean, drug abuse, exotic island, east india ...                en
# 206647    [spy, based on novel, secret agent, sequel, mi...                en
# 49026     [dc comics, crime fighter, terrorist, secret i...                en
# 49529     [based on novel, mars, medallion, space travel...                en
#
# ...

# %%
english_movies_df['overview']=english_movies_df['overview'].apply(lambda x:str(x).split())
# Out:
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/2915783499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df['overview']=english_movies_df['overview'].apply(lambda x:str(x).split())

# %%
english_movies_df.head()
# Out:
#              budget                                         genres  \
# movie_id
# 19995     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285       300000000                   [Adventure, Fantasy, Action]
# 206647    245000000                     [Action, Adventure, Crime]
# 49026     250000000               [Action, Crime, Drama, Thriller]
# 49529     260000000           [Action, Adventure, Science Fiction]
#
#                                                    keywords original_language  \
# movie_id
# 19995     [culture clash, future, space war, space colon...                en
# 285       [ocean, drug abuse, exotic island, east india ...                en
# 206647    [spy, based on novel, secret agent, sequel, mi...                en
# 49026     [dc comics, crime fighter, terrorist, secret i...                en
# 49529     [based on novel, mars, medallion, space travel...                en
#
# ...

# %%
english_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4505 entries, 19995 to 25975
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4505 non-null   int64
#  1   genres                4505 non-null   object
#  2   keywords              4505 non-null   object
#  3   original_language     4505 non-null   object
#  4   overview              4505 non-null   object
#  5   popularity            4505 non-null   float64
#  6   production_companies  4505 non-null   object
#  7   release_date          4504 non-null   object
#  8   revenue               4505 non-null   int64
#  9   runtime               4504 non-null   float64
#  10  tagline               3789 non-null   object
#  11  title_x               4505 non-null   object
#  12  vote_average          4505 non-null   float64
#  13  vote_count            4505 non-null   int64
#  14  cast                  4505 non-null   object
# ...

# %%
english_movies_df.isnull().sum()
# Out:
# budget                    0
# genres                    0
# keywords                  0
# original_language         0
# overview                  0
# popularity                0
# production_companies      0
# release_date              1
# revenue                   0
# runtime                   1
# tagline                 716
# title_x                   0
# vote_average              0
# vote_count                0
# cast                      0
# crew                      0
# dtype: int64

# %%
english_movies_df['tagline']=english_movies_df['tagline'].apply(lambda x:str(x).split())
# Out:
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/2398352323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df['tagline']=english_movies_df['tagline'].apply(lambda x:str(x).split())

# %%
english_movies_df.head()
# Out:
#              budget                                         genres  \
# movie_id
# 19995     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285       300000000                   [Adventure, Fantasy, Action]
# 206647    245000000                     [Action, Adventure, Crime]
# 49026     250000000               [Action, Crime, Drama, Thriller]
# 49529     260000000           [Action, Adventure, Science Fiction]
#
#                                                    keywords original_language  \
# movie_id
# 19995     [culture clash, future, space war, space colon...                en
# 285       [ocean, drug abuse, exotic island, east india ...                en
# 206647    [spy, based on novel, secret agent, sequel, mi...                en
# 49026     [dc comics, crime fighter, terrorist, secret i...                en
# 49529     [based on novel, mars, medallion, space travel...                en
#
# ...

# %%
# clean the tags: remove spaces from it and drop all punctuation/period etc. from tags -->later
all_genres = []
for index, value in english_movies_df['genres'].items():
    for genre in value:
        all_genres.append(genre)

# print(all_genres)
unique_genres = list(set(all_genres))
print(unique_genres)
# Out:
# ['War', 'Thriller', 'Action', 'Horror', 'Comedy', 'Mystery', 'Fantasy', 'History', 'Crime', 'Romance', 'Family', 'Drama', 'Adventure', 'Music', 'Documentary', 'Western', 'Animation', 'TV Movie', 'Science Fiction', 'Foreign']

# %%
main_actors_of_films = []
for index, value in english_movies_df['cast'].items():
    main_actors = []
    for i, actor in enumerate(value):
        if i in range (5):
            main_actors.append(actor)
    english_movies_df.at[index, 'cast'] = main_actors
           
english_movies_df.head()
# Out:
#              budget                                         genres  \
# movie_id
# 19995     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285       300000000                   [Adventure, Fantasy, Action]
# 206647    245000000                     [Action, Adventure, Crime]
# 49026     250000000               [Action, Crime, Drama, Thriller]
# 49529     260000000           [Action, Adventure, Science Fiction]
#
#                                                    keywords original_language  \
# movie_id
# 19995     [culture clash, future, space war, space colon...                en
# 285       [ocean, drug abuse, exotic island, east india ...                en
# 206647    [spy, based on novel, secret agent, sequel, mi...                en
# 49026     [dc comics, crime fighter, terrorist, secret i...                en
# 49529     [based on novel, mars, medallion, space travel...                en
#
# ...

# %%
# main_actors_of_films = []
# for index, value in english_movies_df['cast'].items():
#     main_actors = []
#     for i, actor in enumerate(value):
#         if i in range (3):
#             main_actors.append(actor)
#     english_movies_df.at[index, 'cast'] = main_actors
           
# english_movies_df.head()

english_movies_df.at[285, 'cast']
# Out:
# ['Johnny Depp',
#  'Orlando Bloom',
#  'Keira Knightley',
#  'Stellan Skarsgård',
#  'Chow Yun-fat']

# %%
# Split the 'Values' column into three separate columns
english_movies_df[['Actor1', 'Actor2', 'Actor3','Actor4','Actor5']] = english_movies_df['cast'].apply(pd.Series)
# Out:
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/2662177808.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df[['Actor1', 'Actor2', 'Actor3','Actor4','Actor5']] = english_movies_df['cast'].apply(pd.Series)
# /var/folders/d4/tdg4pkq530l485ywc2m0rsn80000gn/T/ipykernel_97718/2662177808.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_movies_df[['Actor1', 'Actor2', 'Actor3','Actor4','Actor5']] = english_movies_df['cast'].apply(pd.Series)
# ...

# %%
english_movies_df.head()
# Out:
#              budget                                         genres  \
# movie_id
# 19995     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285       300000000                   [Adventure, Fantasy, Action]
# 206647    245000000                     [Action, Adventure, Crime]
# 49026     250000000               [Action, Crime, Drama, Thriller]
# 49529     260000000           [Action, Adventure, Science Fiction]
#
#                                                    keywords original_language  \
# movie_id
# 19995     [culture clash, future, space war, space colon...                en
# 285       [ocean, drug abuse, exotic island, east india ...                en
# 206647    [spy, based on novel, secret agent, sequel, mi...                en
# 49026     [dc comics, crime fighter, terrorist, secret i...                en
# 49529     [based on novel, mars, medallion, space travel...                en
#
# ...

# %%
# Split the 'cast' column into three separate actor columns
# english_movies_df[['Actor1', 'Actor2', 'Actor3']] = english_movies_df['cast'][0]

# Drop the original 'Values' column if needed
english_movies_df = english_movies_df.drop('cast', axis=1)
english_movies_df.head()
# Out:
#              budget                                         genres  \
# movie_id
# 19995     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285       300000000                   [Adventure, Fantasy, Action]
# 206647    245000000                     [Action, Adventure, Crime]
# 49026     250000000               [Action, Crime, Drama, Thriller]
# 49529     260000000           [Action, Adventure, Science Fiction]
#
#                                                    keywords original_language  \
# movie_id
# 19995     [culture clash, future, space war, space colon...                en
# 285       [ocean, drug abuse, exotic island, east india ...                en
# 206647    [spy, based on novel, secret agent, sequel, mi...                en
# 49026     [dc comics, crime fighter, terrorist, secret i...                en
# 49529     [based on novel, mars, medallion, space travel...                en
#
# ...

# %%
movie_record_for_actors = {}
actor_columns = ['Actor1', 'Actor2', 'Actor3','Actor4','Actor5']
for index, row in english_movies_df.iterrows():
    for col in actor_columns:
        # Actor to search for
#         print(type(row))
#         print(col)
    
        target_actor = row[col]
        if target_actor not in movie_record_for_actors:
            # Use boolean indexing to find movies for the target actor
            movies_for_actor = english_movies_df[english_movies_df[['Actor1', 'Actor2', 'Actor3']].isin([target_actor]).any(axis=1)]
            movie_record_for_actors[target_actor] = movies_for_actor
            print("Movies of ", target_actor, "are: ", len(movies_for_actor))
# Out:
# Movies of  Sam Worthington are:  6
# Movies of  Zoe Saldana are:  12
# Movies of  Sigourney Weaver are:  18
# Movies of  Stephen Lang are:  2
# Movies of  Michelle Rodriguez are:  7
# Movies of  Johnny Depp are:  32
# Movies of  Orlando Bloom are:  8
# Movies of  Keira Knightley are:  16
# Movies of  Stellan Skarsgård are:  5
# Movies of  Chow Yun-fat are:  4
# Movies of  Daniel Craig are:  11
# Movies of  Christoph Waltz are:  8
# Movies of  Léa Seydoux are:  1
# Movies of  Ralph Fiennes are:  19
# Movies of  Monica Bellucci are:  3
# Movies of  Christian Bale are:  20
# Movies of  Michael Caine are:  17
# Movies of  Gary Oldman are:  19
# Movies of  Anne Hathaway are:  20
# Movies of  Tom Hardy are:  9
# Movies of  Taylor Kitsch are:  4
# Movies of  Lynn Collins are:  1
# Movies of  Samantha Morton are:  10
# Movies of  Willem Dafoe are:  15
# Movies of  Thomas Haden Church are:  8
# Movies of  Tobey Maguire are:  9
# Movies of  Kirsten Dunst are:  18
# ...

# %%
#now calculate popularity
actor_popularity = {}
for actor, movies in movie_record_for_actors.items():
    popularity_of_actor = 0
    for index, movie in movies.iterrows():
#         print(movie)
        popularity_of_movie = movie['vote_average'] * movie['vote_count']
        popularity_of_actor += popularity_of_movie
    actor_popularity[actor] = popularity_of_actor

# %%
actor_popularity
# Out:
# {'Sam Worthington': 128654.5,
#  'Zoe Saldana': 219092.40000000002,
#  'Sigourney Weaver': 182550.80000000002,
#  'Stephen Lang': 664.0999999999999,
#  'Michelle Rodriguez': 57815.200000000004,
#  'Johnny Depp': 426737.69999999984,
#  'Orlando Bloom': 155154.30000000002,
#  'Keira Knightley': 190043.2,
#  'Stellan Skarsgård': 4776.6,
#  'Chow Yun-fat': 3704.6000000000004,
#  'Daniel Craig': 178751.79999999996,
#  'Christoph Waltz': 196944.3,
#  'Léa Seydoux': 28135.8,
#  'Ralph Fiennes': 143107.1,
#  'Monica Bellucci': 18154.800000000003,
#  'Christian Bale': 398624.49999999994,
#  'Michael Caine': 204043.6,
#  'Gary Oldman': 204511.50000000003,
#  'Anne Hathaway': 243881.09999999995,
#  'Tom Hardy': 151636.5,
#  'Taylor Kitsch': 40625.0,
#  'Lynn Collins': 12956.4,
#  'Samantha Morton': 37032.1,
#  'Willem Dafoe': 83504.20000000001,
#  'Thomas Haden Church': 18788.100000000002,
#  'Tobey Maguire': 128978.09999999998,
#  'Kirsten Dunst': 154379.6,
#  'James Franco': 182178.7,
# ...

# %%
# Sort the dictionary by values in descending order
sorted_actor_popularity = sorted(actor_popularity.items(), key=lambda x: x[1], reverse=True)

# Extract the top 10 items
top_10_actors = dict(sorted_actor_popularity[:10])

# Display the top 10 items
print(top_10_actors)
# Out:
# {'Leonardo DiCaprio': 573244.2000000001, 'Robert Downey Jr.': 485870.9000000001, 'Brad Pitt': 479033.80000000005, 'Tom Hanks': 471864.99999999994, 'Johnny Depp': 426737.69999999984, 'Ian McKellen': 418728.5999999999, 'Christian Bale': 398624.49999999994, 'Matt Damon': 396771.0999999999, 'Will Smith': 345295.60000000003, 'Harrison Ford': 336620.30000000005}

# %%
english_movies_df['crew'][285]
# Out:
# '[{"credit_id": "52fe4232c3a36847f800b579", "department": "Camera", "gender": 2, "id": 120, "job": "Director of Photography", "name": "Dariusz Wolski"}, {"credit_id": "52fe4232c3a36847f800b4fd", "department": "Directing", "gender": 2, "id": 1704, "job": "Director", "name": "Gore Verbinski"}, {"credit_id": "52fe4232c3a36847f800b54f", "department": "Production", "gender": 2, "id": 770, "job": "Producer", "name": "Jerry Bruckheimer"}, {"credit_id": "52fe4232c3a36847f800b503", "department": "Writing", "gender": 2, "id": 1705, "job": "Screenplay", "name": "Ted Elliott"}, {"credit_id": "52fe4232c3a36847f800b509", "department": "Writing", "gender": 2, "id": 1706, "job": "Screenplay", "name": "Terry Rossio"}, {"credit_id": "52fe4232c3a36847f800b57f", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "52fe4232c3a36847f800b585", "department": "Editing", "gender": 2, "id": 1722, "job": "Editor", "name": "Craig Wood"}, {"credit_id": "5
# ...

# %%
def extract_director_from_json(json_str):
#     tags = []
    # Parse the JSON-formatted string into a list of dictionaries
    try:
        json_obj = json.loads(json_str)
    except json.JSONDecodeError:
        print("Error decoding JSON string.")
        return []
    
    for obj in json_obj:
        if obj["job"] == "Director":
            return obj["name"]

# %%
english_movies_df['crew']=english_movies_df['crew'].apply(extract_director_from_json)
english_movies_df.rename(columns={'crew': 'director'}, inplace=True)

# %%
english_movies_df.head()
# Out:
#              budget                                         genres  \
# movie_id
# 19995     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285       300000000                   [Adventure, Fantasy, Action]
# 206647    245000000                     [Action, Adventure, Crime]
# 49026     250000000               [Action, Crime, Drama, Thriller]
# 49529     260000000           [Action, Adventure, Science Fiction]
#
#                                                    keywords original_language  \
# movie_id
# 19995     [culture clash, future, space war, space colon...                en
# 285       [ocean, drug abuse, exotic island, east india ...                en
# 206647    [spy, based on novel, secret agent, sequel, mi...                en
# 49026     [dc comics, crime fighter, terrorist, secret i...                en
# 49529     [based on novel, mars, medallion, space travel...                en
#
# ...

# %%
# Check for NaN values in a specific column
nan_values = english_movies_df['director'].isna().sum()

# Alternatively, you can use isnull()
# nan_values = english_movies_df['your_column'].isnull().sum()

print(f'Number of NaN values in the column: {nan_values}')
print(nan_values)
# Out:
# Number of NaN values in the column: 30
# 30

# %%
# Remove rows with empty director lists
# english_movies_df = english_movies_df[english_movies_df['director'].apply(lambda x: len(x) > 0)]

# # Reset index after removing rows
# english_movies_df.reset_index(drop=True, inplace=True)
# Remove rows where 'director' column is NaN
english_movies_df = english_movies_df.dropna(subset=['director'])
english_movies_df.reset_index(drop=True, inplace=True)

# Display the updated DataFrame
print(english_movies_df.head())
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577
# ...

# %%
# check for empty director list
empty_director_lists = english_movies_df['director'].apply(lambda x: len(x) == 0)
movies_with_empty_director = english_movies_df[empty_director_lists]
display(len(movies_with_empty_director))
display(movies_with_empty_director)
# Out:
# 0
# Empty DataFrame
# Columns: [budget, genres, keywords, original_language, overview, popularity, production_companies, release_date, revenue, runtime, tagline, title_x, vote_average, vote_count, director, Actor1, Actor2, Actor3, Actor4, Actor5]
# Index: []

# %%
# Check for NaN values in specific columns
nan_values = english_movies_df[['Actor1', 'Actor2', 'Actor3','Actor4','Actor5']].isna().any(axis=1)

# Get rows with NaN values in the specified columns
rows_with_nan = english_movies_df[nan_values]

# Display rows with NaN values
display(rows_with_nan)
display(len(rows_with_nan))
# Out:
#         budget                                       genres  \
# 1426         0                    [Fantasy, Family, Action]
# 2230         0  [Animation, Drama, Family, Science Fiction]
# 2312         0                                     [Horror]
# 2515  15000000                         [Music, Documentary]
# 2525         0                                     [Family]
# ...        ...                                          ...
# 4454         0                                     [Comedy]
# 4457         0                              [Drama, Family]
# 4459         0                     [Drama, Comedy, Romance]
# 4465        13                                     [Horror]
# 4470         0                          [Foreign, Thriller]
#
#                                                keywords original_language  \
# 1426  [american football, mythology, chinese food, k...                en
# 2230                                                 []                en
# ...

# %%
# Specify the three columns
columns_to_check = ['Actor1', 'Actor2', 'Actor3','Actor4','Actor5']

# Drop rows where all three columns have NaN values
english_movies_df = english_movies_df.dropna(subset=columns_to_check, how='all')

# Reset index after dropping rows
df_without_nan.reset_index(drop=True, inplace=True)

display(english_movies_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ravanranveer/Downloads/Project/Untitled.ipynb Cell 59 line 8
#       <a href='vscode-notebook-cell:/Users/ravanranveer/Downloads/Project/Untitled.ipynb#Y112sZmlsZQ%3D%3D?line=4'>5</a> english_movies_df = english_movies_df.dropna(subset=columns_to_check, how='all')
#       <a href='vscode-notebook-cell:/Users/ravanranveer/Downloads/Project/Untitled.ipynb#Y112sZmlsZQ%3D%3D?line=6'>7</a> # Reset index after dropping rows
# ----> <a href='vscode-notebook-cell:/Users/ravanranveer/Downloads/Project/Untitled.ipynb#Y112sZmlsZQ%3D%3D?line=7'>8</a> df_without_nan.reset_index(drop=True, inplace=True)
#      <a href='vscode-notebook-cell:/Users/ravanranveer/Downloads/Project/Untitled.ipynb#Y112sZmlsZQ%3D%3D?line=9'>10</a> display(english_movies_df)
#
# NameError: name 'df_without_nan' is not defined

# %%
# english_movies_df['director']=english_movies_df['director'].apply(lambda x:x[0])

# %%
movie_record_for_directors = {}
for index, row in english_movies_df.iterrows():
    target_director = row['director']
#     print(target_director)
    if target_director not in movie_record_for_directors:
        # Use boolean indexing to find movies for the target actor
        movies_for_director = english_movies_df[english_movies_df['director'].isin([target_director])]
        movie_record_for_directors[target_director] = movies_for_director
        print("Movies of ", target_director, "are: ", len(movies_for_director))
# Out:
# Movies of  James Cameron are:  7
# Movies of  Gore Verbinski are:  7
# Movies of  Sam Mendes are:  7
# Movies of  Christopher Nolan are:  8
# Movies of  Andrew Stanton are:  4
# Movies of  Sam Raimi are:  11
# Movies of  Byron Howard are:  1
# Movies of  Joss Whedon are:  3
# Movies of  David Yates are:  3
# Movies of  Zack Snyder are:  7
# Movies of  Bryan Singer are:  8
# Movies of  Marc Forster are:  8
# Movies of  Andrew Adamson are:  5
# Movies of  Rob Marshall are:  5
# Movies of  Barry Sonnenfeld are:  7
# Movies of  Peter Jackson are:  9
# Movies of  Marc Webb are:  3
# Movies of  Ridley Scott are:  16
# Movies of  Chris Weitz are:  6
# Movies of  Anthony Russo are:  4
# Movies of  Peter Berg are:  6
# Movies of  Colin Trevorrow are:  2
# Movies of  Shane Black are:  2
# Movies of  Tim Burton are:  14
# Movies of  Brett Ratner are:  9
# Movies of  Dan Scanlon are:  1
# Movies of  Michael Bay are:  12
# Movies of  Joseph Kosinski are:  2
# Movies of  John Lasseter are:  4
# ...

# %%
#now calculate popularity
director_popularity = {}
for director, movies in movie_record_for_directors.items():
    popularity_of_director = 0
    for index, movie in movies.iterrows():
#         print(movie)
        popularity_of_movie = movie['vote_average'] * movie['vote_count']
        popularity_of_director += popularity_of_movie
    director_popularity[director] = popularity_of_director

# %%
# Sort the dictionary by values in descending order
sorted_director_popularity = sorted(director_popularity.items(), key=lambda x: x[1], reverse=True)

# Extract the top 10 items
top_10_directors = dict(sorted_director_popularity[:10])

# Display the top 10 items
print(top_10_directors)
# Out:
# {'Christopher Nolan': 497789.60000000003, 'Steven Spielberg': 431883.2999999999, 'Peter Jackson': 345623.0, 'Quentin Tarantino': 340744.30000000005, 'David Fincher': 281189.7, 'Ridley Scott': 260574.8, 'Martin Scorsese': 253011.2, 'Robert Zemeckis': 247910.3, 'James Cameron': 242153.49999999997, 'Tim Burton': 194046.39999999997}

# %%
# check for empty production_company list
empty_pc_lists = english_movies_df['production_companies'].apply(lambda x: len(x) == 0)
movies_with_empty_pc = english_movies_df[empty_pc_lists]
display(len(movies_with_empty_pc))
display(movies_with_empty_pc)
# Out:
# 277
#         budget                              genres  \
# 1333         0                             [Drama]
# 1714  27000000  [Adventure, Comedy, Drama, Family]
# 1857  26000000                    [Comedy, Family]
# 1895         0                     [Comedy, Crime]
# 1939         0                    [Romance, Drama]
# ...        ...                                 ...
# 4460         0                             [Drama]
# 4461         0                   [Comedy, Romance]
# 4464         0                             [Drama]
# 4471      9000                   [Comedy, Romance]
# 4473         0                                  []
#
#                                                keywords original_language  \
# 1333  [spanish civil war, priest, independent film, ...                en
# 1714  [female friendship, best friend, summer vacati...                en
# 1857                                          [holiday]                en
# ...

# %%
# there are 277 rows with empty production companies, in our assumption production_company wouldn't matter as much as director or actors 
# because in a movie trailer for example, movies aren't advertised by name-dropping production_companies
# so instead of removing rows with empty production_companies, I will put their popularity as 0, so it may affect a little but assuming the production_comapnies
# don't matter that much, that 0 will skew the results awfully

movie_record_for_pc = {}
for index, row in english_movies_df.iterrows():
    target_list_of_pc = row['production_companies']
    if(len(target_list_of_pc) != 0):
        for pc in target_list_of_pc:
            if pc not in movie_record_for_pc:
                movies_for_pc = english_movies_df[english_movies_df['production_companies'].apply(lambda x: pc in x)]
                movie_record_for_pc[pc] = movies_for_pc
                print("Movies of ", pc, "are: ", len(movies_for_pc))
# Out:
# Movies of  Ingenious Film Partners are:  29
# Movies of  Twentieth Century Fox Film Corporation are:  220
# Movies of  Dune Entertainment are:  59
# Movies of  Lightstorm Entertainment are:  5
# Movies of  Walt Disney Pictures are:  113
# Movies of  Jerry Bruckheimer Films are:  21
# Movies of  Second Mate Productions are:  2
# Movies of  Columbia Pictures are:  198
# Movies of  Danjaq are:  8
# Movies of  B24 are:  1
# Movies of  Legendary Pictures are:  34
# Movies of  Warner Bros. are:  316
# Movies of  DC Entertainment are:  12
# Movies of  Syncopy are:  8
# Movies of  Laura Ziskin Productions are:  5
# Movies of  Marvel Enterprises are:  16
# Movies of  Walt Disney Animation Studios are:  8
# Movies of  Marvel Studios are:  13
# Movies of  Prime Focus are:  1
# Movies of  Revolution Sun Studios are:  16
# Movies of  Heyday Films are:  10
# Movies of  DC Comics are:  15
# Movies of  Atlas Entertainment are:  13
# Movies of  Cruel & Unusual Films are:  1
# ...

# %%
#now calculate popularity
pc_popularity = {}
for pc, movies in movie_record_for_pc.items():
    popularity_of_pc = 0
    for index, movie in movies.iterrows():
#         print(movie)
        popularity_of_movie = movie['vote_average'] * movie['vote_count']
        popularity_of_pc += popularity_of_movie
    pc_popularity[pc] = popularity_of_pc

# %%
# Sort the dictionary by values in descending order
sorted_pc_popularity = sorted(pc_popularity.items(), key=lambda x: x[1], reverse=True)

# Extract the top 10 items
top_10_pc = dict(sorted_pc_popularity[:10])

# Display the top 10 items
print(top_10_pc)
# Out:
# {'Warner Bros.': 2993639.4999999986, 'Universal Pictures': 2108854.6000000006, 'Paramount Pictures': 1947716.5000000002, 'Twentieth Century Fox Film Corporation': 1925577.7999999998, 'Columbia Pictures': 1427589.6999999995, 'Walt Disney Pictures': 1185488.5999999992, 'New Line Cinema': 1056761.9999999998, 'Legendary Pictures': 849804.9999999999, 'Village Roadshow Pictures': 785353.4999999997, 'Amblin Entertainment': 686083.8999999999}

# %%
#Feature extraction is done for cast, crew and production company popularity

# %%
# create new columns for popularity of each of the columns: Actor1_popularity, Actor2_popularity, Actor3_popularity, director_popularity, production_companies_populairty

english_movies_df['Actor1_popularity'] = english_movies_df.apply(lambda row: actor_popularity.get(row['Actor1']), axis=1)
english_movies_df['Actor2_popularity'] = english_movies_df.apply(lambda row: actor_popularity.get(row['Actor2']), axis=1)
english_movies_df['Actor3_popularity'] = english_movies_df.apply(lambda row: actor_popularity.get(row['Actor3']), axis=1)
english_movies_df['Actor4_popularity'] = english_movies_df.apply(lambda row: actor_popularity.get(row['Actor4']), axis=1)
english_movies_df['Actor5_popularity'] = english_movies_df.apply(lambda row: actor_popularity.get(row['Actor5']), axis=1)

english_movies_df.reset_index(drop=True, inplace=True)

# %%
english_movies_df.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577
# ...

# %%
english_movies_df['director_popularity'] = english_movies_df.apply(lambda row: director_popularity.get(row['director']), axis=1)
english_movies_df.reset_index(drop=True, inplace=True)

# %%
english_movies_df.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577
# ...

# %%
def get_total_pc_popularity_for_movie(target_list_of_pc):
    total_pc_popularity_for_movie = 0
    if(len(target_list_of_pc) != 0):
        for pc in target_list_of_pc:
            total_pc_popularity_for_movie += pc_popularity.get(pc)

        return total_pc_popularity_for_movie   
    else:
        return 0
    
english_movies_df['production_companies_populairty'] = english_movies_df['production_companies'].apply(get_total_pc_popularity_for_movie)
english_movies_df.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577
# ...

# %%
all_genres = []
for index, value in english_movies_df['genres'].items():
    for genre in value:
        all_genres.append(genre)

# print(all_genres)
unique_genres = list(set(all_genres))
print(unique_genres)

# Add new columns to the DataFrame for each genre:
for genre in unique_genres:
    english_movies_df[genre] = 0
    
english_movies_df.reset_index(drop=True, inplace=True)
display(english_movies_df.info())
english_movies_df.head()
# Out:
# ['War', 'Thriller', 'Action', 'Horror', 'Comedy', 'Mystery', 'Fantasy', 'History', 'Crime', 'Romance', 'Family', 'Drama', 'Adventure', 'Music', 'Documentary', 'Western', 'Animation', 'TV Movie', 'Science Fiction', 'Foreign']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4454 entries, 0 to 4453
# Data columns (total 47 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   budget                           4454 non-null   int64
#  1   genres                           4454 non-null   object
#  2   keywords                         4454 non-null   object
#  3   original_language                4454 non-null   object
#  4   overview                         4454 non-null   object
#  5   popularity                       4454 non-null   float64
#  6   production_companies             4454 non-null   object
#  7   release_date                     4454 non-null   object
# ...

# %%
# def set_genres_for_movie(list_of_genres):
#     if(len(target_list_of_pc) != 0):
#         for genre in list_of_genres:
#             english_movies_df[genre] = 1

# english_movies_df['genres'].apply(set_genres_for_movie)
# english_movies_df.head()

def set_genres_for_movie(row):
    list_of_genres = row['genres']
    if len(list_of_genres) != 0:
        for genre in list_of_genres:
            english_movies_df.at[row.name, genre] = 1

# Apply the function to each row
english_movies_df.apply(set_genres_for_movie, axis=1)
english_movies_df.reset_index(drop=True, inplace=True)

# Display the DataFrame
english_movies_df.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577
# ...

# %%
#Create a new column named tags to store all necessary info about each movies: overview, keywords, tagline
english_movies_df.rename(columns={'title_x': 'title'}, inplace=True)
# english_movies_df['tags']= english_movies_df['overview']+ english_movies_df['keywords']+ english_movies_df['tagline']+ english_movies_df['title']
# english_movies_df = english_movies_df.drop('overview', axis=1)
# english_movies_df = english_movies_df.drop('keywords', axis=1)
# english_movies_df = english_movies_df.drop('tagline', axis=1)
# english_movies_df.head()

# %%
# Convert lists to strings
english_movies_df['overview'] = english_movies_df['overview'].apply(lambda x: ' '.join(x) if isinstance(x, list) else '')
english_movies_df['keywords'] = english_movies_df['keywords'].apply(lambda x: ' '.join(x) if isinstance(x, list) else '')
english_movies_df['tagline'] = english_movies_df['tagline'].apply(lambda x: ' '.join(x) if isinstance(x, list) else '')
# english_movies_df['title'] = english_movies_df['title'].apply(lambda x: str(x))

# Create a new column 'tags' by concatenating the strings
english_movies_df['tags'] = english_movies_df['overview'] + english_movies_df['keywords'] + english_movies_df['tagline'] + english_movies_df['title']

# Drop the original columns
# english_movies_df = english_movies_df.drop(['overview', 'keywords', 'tagline'], axis=1)
# english_movies_df.reset_index(drop=True, inplace=True)

# Display the DataFrame
(english_movies_df.head())
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2  spy based on novel secret agent sequel mi6 bri...                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
english_movies_df['tags'][1]
# Out:
# "Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.ocean drug abuse exotic island east india trading company love of one's life traitor shipwreck strong woman ship alliance calypso afterlife fighter pirate swashbuckler aftercreditsstingerAt the end of the world, the adventure begins.Pirates of the Caribbean: At World's End"

# %%
# Concatenate the tags into a string
# english_movies_df['tags'] = english_movies_df['tags'].apply(lambda tags: ','.join(tags))

# %%
# english_movies_df['tags']=english_movies_df['tags'].apply(lambda x:str(x).split())

# %%
english_movies_df.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2  spy based on novel secret agent sequel mi6 bri...                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
# english_movies_df['tags']=english_movies_df['tags'].apply(lambda x:str(x).split())

# %%
# english_movies_df.reset_index(drop=True, inplace=True)
# english_movies_df['tags'][1]

# %%
## in the end we drop all column that we're done extracting from

# %%
# exploration: cast ids don't mean much except conveying identity: can't extract leading actors based on id: can extrapolate and say the same for crew
df_credits_temp = pd.read_csv('tmdb_5000_credits.csv')
main_actors_of_films = []
for index, value in df_credits_temp['cast'].items():
    main_actors = []
#     print(value)
    try:
        json_obj = json.loads(value)
    except json.JSONDecodeError:
        print("Error decoding JSON string.")

    for obj in json_obj:
        if obj["id"] in range (1, 50):
            main_actors.append(obj["name"])
           
    main_actors_of_films.append((df_credits_temp.at[index, 'title'],main_actors))
           
print(main_actors_of_films)
# Out:
# [('Avatar', []), ("Pirates of the Caribbean: At World's End", []), ('Spectre', []), ('The Dark Knight Rises', []), ('John Carter', []), ('Spider-Man 3', []), ('Tangled', ['Brad Garrett']), ('Avengers: Age of Ultron', []), ('Harry Potter and the Half-Blood Prince', []), ('Batman v Superman: Dawn of Justice', []), ('Superman Returns', []), ('Quantum of Solace', []), ("Pirates of the Caribbean: Dead Man's Chest", []), ('The Lone Ranger', []), ('Man of Steel', []), ('The Chronicles of Narnia: Prince Caspian', []), ('The Avengers', []), ('Pirates of the Caribbean: On Stranger Tides', []), ('Men in Black 3', []), ('The Hobbit: The Battle of the Five Armies', []), ('The Amazing Spider-Man', ['Sally Field']), ('Robin Hood', []), ('The Hobbit: The Desolation of Smaug', []), ('The Golden Compass', []), ('King Kong', []), ('Titanic', []), ('Captain America: Civil War', []), ('Battleship', []), ('Jurassic World', []), ('Skyfall', []), ('Spider-Man 2', []), ('Iron Man 3', []), ('Alice in Wonderla
# ...

# %%
# exploration: but we can take the first 5 objects and the objects are ordered in the order of screen/time or significance
df_credits_temp = pd.read_csv('tmdb_5000_credits.csv')

main_actors_of_films = []
for index, value in df_credits_temp['cast'].items():
    main_actors = []
#     print(value)
    try:
        json_obj = json.loads(value)
    except json.JSONDecodeError:
        print("Error decoding JSON string.")

    for i, obj in enumerate(json_obj):
        if i in range (5):
            main_actors.append(obj["name"])
           
    main_actors_of_films.append((df_credits_temp.at[index, 'title'],main_actors))
           
print(main_actors_of_films)
# Out:
# [('Avatar', ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver', 'Stephen Lang', 'Michelle Rodriguez']), ("Pirates of the Caribbean: At World's End", ['Johnny Depp', 'Orlando Bloom', 'Keira Knightley', 'Stellan Skarsgård', 'Chow Yun-fat']), ('Spectre', ['Daniel Craig', 'Christoph Waltz', 'Léa Seydoux', 'Ralph Fiennes', 'Monica Bellucci']), ('The Dark Knight Rises', ['Christian Bale', 'Michael Caine', 'Gary Oldman', 'Anne Hathaway', 'Tom Hardy']), ('John Carter', ['Taylor Kitsch', 'Lynn Collins', 'Samantha Morton', 'Willem Dafoe', 'Thomas Haden Church']), ('Spider-Man 3', ['Tobey Maguire', 'Kirsten Dunst', 'James Franco', 'Thomas Haden Church', 'Topher Grace']), ('Tangled', ['Zachary Levi', 'Mandy Moore', 'Donna Murphy', 'Ron Perlman', 'M.C. Gainey']), ('Avengers: Age of Ultron', ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo', 'Chris Evans', 'Scarlett Johansson']), ('Harry Potter and the Half-Blood Prince', ['Daniel Radcliffe', 'Rupert Grint', 'Emma Watson', 'Tom Felton', '
# ...

# %%
# exploration: let's try the same for crew
df_credits_temp = pd.read_csv('tmdb_5000_credits.csv')
main_actors_of_films = []
for index, value in df_credits_temp['crew'].items():
    main_actors = []
#     print(value)
    try:
        json_obj = json.loads(value)
    except json.JSONDecodeError:
        print("Error decoding JSON string.")

    for i, obj in enumerate(json_obj):
        if i in range (5):
            main_actors.append(obj["name"])
           
    main_actors_of_films.append((df_credits_temp.at[index, 'title'],main_actors))
           
print(main_actors_of_films)
# Out:
# [('Avatar', ['Stephen E. Rivkin', 'Rick Carter', 'Christopher Boyes', 'Christopher Boyes', 'Mali Finn']), ("Pirates of the Caribbean: At World's End", ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Bruckheimer', 'Ted Elliott', 'Terry Rossio']), ('Spectre', ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock', 'John Logan', 'John Logan']), ('The Dark Knight Rises', ['Hans Zimmer', 'Charles Roven', 'Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan']), ('John Carter', ['Andrew Stanton', 'Andrew Stanton', 'John Lasseter', 'Colin Wilson', 'Gail Stevens']), ('Spider-Man 3', ['Francine Maisler', 'Joseph M. Caracciolo Jr.', 'Sam Raimi', 'Sam Raimi', 'Stan Lee']), ('Tangled', ['John Lasseter', 'Jacob Grimm', 'Wilhelm Grimm', 'John Kahrs', 'Douglas Rogers']), ('Avengers: Age of Ultron', ['Danny Elfman', 'Christopher Boyes', 'Christopher Boyes', 'Sarah Finn', 'Brian Tyler']), ('Harry Potter and the Half-Blood Prince', ['Bruno Delbonnel', 'Stephanie McMillan', 'Stuart Craig', 'J.K. Rowling', '
# ...

# %%
def get_important_info(df, column_name, pk):
    info_for_df = []
    for index, value in df[column_name].items():
        info_per_movie = []
    #     print(value)
        try:
            json_obj = json.loads(value)
        except json.JSONDecodeError:
            print("Error decoding JSON string.")

        for i, obj in enumerate(json_obj):
            if i in range (5):
                info_per_movie.append(obj["name"])

        info_for_df.append((df.at[index, pk], info_per_movie))
    return info_for_df
    

imp_actors = get_important_info(df_credits_temp, 'cast', 'title')

# %%
all_actors = []
for pair in imp_actors:
    all_actors += pair[1]
unique_actors = list(set(all_actors))
print(len(unique_actors))
print(unique_actors)
# Out:
# 9390
# ...

# %%
all_actors = []
for pair in imp_actors:
    all_actors += pair[1]
unique_actors = list(set(all_actors))
print(len(unique_actors))
print(unique_actors)
# Out:
# 9390
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Example categorical labels
labels = unique_actors

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the labels
encoded_labels = label_encoder.fit_transform(labels)

# Display the result
print("Original labels:", labels)
print("Encoded labels:", encoded_labels)
# Out:
# Original labels: ['Adriana Caselotti', 'Devon Sawa', 'William Shatner', 'Tate Donovan', 'Kelly McGillis', 'Phil Dunster', 'Emma Caulfield', 'Michael Michele', 'Jenna Fischer', 'Marie Drion', 'Rain', 'Djimon Hounsou', 'Michael Kanev', 'Amber Armstrong', 'Walter Phelan', 'Kristen Quintrall', 'Andy Nyman', 'Sarah Berry', 'Steve Moses', 'Luke Mably', 'Cindy Manion', 'Rob LaBelle', 'Noah Emmerich', 'Staffan Kihlbom', 'Lee Jung-jae', 'Tamala Jones', 'Ken Davitian', 'Darryl Stephens', 'Darren Shahlavi', 'Erica Tazel', 'Pamela Gidley', 'Manny Pérez', 'Hank Azaria', 'Roy Dotrice', 'Richie Ren', 'Ron Rifkin', 'Rüdiger Evers', 'Taylor Pigeon', 'Bruce McGill', 'Brendan Gleeson', 'François Berléand', 'Robert Hays', 'Xu Jiao', 'Renee Leblanc', 'Lee Remick', 'Jaimz Woolvett', 'Jeannie Berlin', 'Carly Schroeder', 'Mickey Sumner', 'Archie Panjabi', 'Steve Guttenberg', 'Akiko Takeshita', 'Amara Miller', 'Tyra Ferrell', 'Geoff Gustafson', 'Hill Harper', 'Jim Henson', 'Ted Wass', 'Eugene Roche', 'Dan Le
# ...

# %%
df_credits_temp = pd.read_csv('tmdb_5000_credits.csv')
df_credits_temp['cast']
# Out:
# 0       [{"cast_id": 242, "character": "Jake Sully", "...
# 1       [{"cast_id": 4, "character": "Captain Jack Spa...
# 2       [{"cast_id": 1, "character": "James Bond", "cr...
# 3       [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       [{"cast_id": 5, "character": "John Carter", "c...
#                               ...
# 4798    [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799    [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800    [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801    [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802    [{"cast_id": 3, "character": "Herself", "credi...
# Name: cast, Length: 4803, dtype: object

# %%
def get_all_actors_crew(df, column_name, pk):
    info_for_df = []
    for index, value in df[column_name].items():
        info_per_movie = []
    #     print(value)
        try:
            json_obj = json.loads(value)
        except json.JSONDecodeError:
            print("Error decoding JSON string.")

        for i, obj in enumerate(json_obj):
                info_per_movie.append(obj["name"])

        info_for_df.append((df.at[index, pk], info_per_movie))
    return info_for_df
    

imp_actors = get_important_info(df_credits_temp, 'cast', 'title')

# %%
english_movies_df.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2  spy based on novel secret agent sequel mi6 bri...                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
english_movies_df.drop(columns=['Foreign','Actor1','Actor2','Actor3','Actor4','Actor5','director','genres'])
# Out:
#          budget                                           keywords  \
# 0     237000000  culture clash future space war space colony so...
# 1     300000000  ocean drug abuse exotic island east india trad...
# 2     245000000  spy based on novel secret agent sequel mi6 bri...
# 3     250000000  dc comics crime fighter terrorist secret ident...
# 4     260000000  based on novel mars medallion space travel pri...
# ...         ...                                                ...
# 4449       7000  distrust garage identity crisis time travel ti...
# 4450       9000
# 4451          0  date love at first sight narration investigati...
# 4452          0
# 4453          0               obsession camcorder crush dream girl
#
#      original_language                                           overview  \
# 0                   en  In the 22nd century, a paraplegic Marine is di...
# 1                   en  Captain Barbossa, long believed to be dead, ha...
# ...

# %%
english_movies_df['tags'] = english_movies_df['tags'].str.replace(r'[,\.\-\']', '', regex=True)

# %%
english_movies_df.head().tags
# Out:
# 0    In the 22nd century a paraplegic Marine is dis...
# 1    Captain Barbossa long believed to be dead has ...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a warweary former military capt...
# Name: tags, dtype: object

# %%
# from sklearn.model_selection import train_test_split

# # Specify features and target variable

# X = df[['feature1', 'feature2']]
# y = df['target']

# # Split the data into training (70%) and testing (30%) sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# # Display the shapes of the resulting sets
# print("Training set shape:", X_train.shape, y_train.shape)
# print("Testing set shape:", X_test.shape, y_test.shape)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
tfidf_vectorizer = TfidfVectorizer()


# Fit and transform your 'tags' data
tfidf_matrix = tfidf_vectorizer.fit_transform(english_movies_df['tags'])

# tfidf_matrix = tfidf_vectorizer.fit_transform(df['tags'])

# # pca = PCA(n_components=1000)  # Adjust n_components as needed
# # tfidf_matrix_reduced = pca.fit_transform(tfidf_matrix)
n_components = 1000 
svd = TruncatedSVD(n_components=n_components)  # Adjust n_components as needed
tfidf_matrix_reduced = svd.fit_transform(tfidf_matrix)

# # Get the names of the new components (columns)
component_names = [f"Component_{i+1}" for i in range(n_components)]

# # Create a DataFrame with the reduced matrix and component names
df_reduced = pd.DataFrame(data=tfidf_matrix_reduced, columns=component_names)

# Convert the matrix to a DataFrame and print the components along with values



# Combine the TF-IDF DataFrame with the original DataFrame
# num_components = 10  # Choose the number of components
# nmf = NMF(n_components=num_components)

# # Fit NMF to the TF-IDF matrix
# nmf.fit(tfidf_matrix)

# Transform the data
# nmf_features = nmf.transform(tfidf_matrix)

# # Create a DataFrame with the transformed features
# nmf_df = pd.DataFrame(nmf_features, columns=[f"component_{i+1}" for i in range(num_components)])
# print("Transformed DataFrame:")
# print(nmf_df)

# # Print the components
# components_df = pd.DataFrame(nmf.components_, columns=tfidf_vectorizer.get_feature_names_out())
# print("\nComponents:")
# print(components_df)

# Display the result
# Out:
# Transformed DataFrame:
#       component_1  component_2  component_3  component_4  component_5  \
# 0        0.000000     0.000000     0.000000     0.000000     0.011414
# 1        0.059916     0.011922     0.015995     0.008668     0.028222
# 2        0.013946     0.000000     0.000000     0.000000     0.000000
# 3        0.028865     0.000000     0.003572     0.000000     0.000000
# 4        0.016559     0.000000     0.023391     0.000000     0.007466
# ...           ...          ...          ...          ...          ...
# 4449     0.023527     0.000000     0.009604     0.096184     0.002850
# 4450     0.021418     0.000000     0.000000     0.034006     0.000000
# 4451     0.040673     0.000000     0.000000     0.025871     0.025241
# 4452     0.018515     0.002850     0.053725     0.005026     0.000000
# 4453     0.009760     0.044003     0.032301     0.000000     0.001179
#
#       component_6  component_7  component_8  component_9  component_10
# ...

# %%
result_df = pd.concat([english_movies_df, nmf_df], axis=1)

# %%
# Dimensionality reduction: Used PCA didn't work with data, now using Truncated SVD
display(result_df)
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4449       7000             [Science Fiction, Drama, Thriller]
# 4450       9000                              [Comedy, Romance]
# 4451          0             [Comedy, Drama, Romance, TV Movie]
# 4452          0                                             []
# 4453          0                                  [Documentary]
#
#                                                keywords original_language  \
# 0     culture clash future space war space colony so...                en
# ...

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# import pandas as pd
# from sklearn.decomposition import PCA
# from sklearn.decomposition import TruncatedSVD

# # Example data (replace this with your own dataset)
# # data = {'document_id': english_movies_df[],
# #         'text': ['This is the first document.',
# #                  'This document is the second document.',
# #                  'And this is the third one.']}

# df = english_movies_df

# # Create a TfidfVectorizer
# tfidf_vectorizer = TfidfVectorizer()

# # Fit and transform the text data
# tfidf_matrix = tfidf_vectorizer.fit_transform(df['tags'])

# # pca = PCA(n_components=1000)  # Adjust n_components as needed
# # tfidf_matrix_reduced = pca.fit_transform(tfidf_matrix)
# n_components = 1000 
# svd = TruncatedSVD(n_components=n_components)  # Adjust n_components as needed
# tfidf_matrix_reduced = svd.fit_transform(tfidf_matrix)

# # Get the names of the new components (columns)
# component_names = [f"Component_{i+1}" for i in range(n_components)]

# # Create a DataFrame with the reduced matrix and component names
# df_reduced = pd.DataFrame(data=tfidf_matrix_reduced, columns=component_names)


# # Combine the TF-IDF DataFrame with the original DataFrame
# result_df = pd.concat([df, df_reduced], axis=1)

# # Display the result

# display(result_df)
components_df
# Out:
#          00       000       007    007for  007moonraker  007never  007video  \
# 0  0.000000  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000
# 1  0.001945  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000
# 5  0.003454  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000
# 6  0.009381  0.000000  0.062883  0.007411      0.000755  0.007249  0.007249
# 7  0.000000  0.010535  0.000000  0.000000      0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000
# 9  0.000000  0.000000  0.000000  0.000000      0.011560  0.000000  0.000000
#
#          05  06mission      07am  ...      zula    zurich      zuzu  \
# ...

# %%
# # Display the feature names associated with each component
# for i, component in enumerate(svd.components_):
#     print(f"\nTop words for Component_{i+1}:")
#     top_words_indices = component.argsort()[-10:][::-1]  # Adjust the number of top words as needed
#     top_words = [feature_names[idx] for idx in top_words_indices]
#     print(top_words)

# %%
# df = english_movies_df

# # Custom tokenizer that splits on whitespace
# def custom_tokenizer(text):
#     return text.split()

# # Create a TfidfVectorizer with the custom tokenizer
# tfidf_vectorizer = TfidfVectorizer(tokenizer=custom_tokenizer)

# # Fit and transform the text data
# tfidf_matrix = tfidf_vectorizer.fit_transform(df['tags'])

# # Convert the TF-IDF matrix to a DataFrame for better visualization
# tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

# # Combine the TF-IDF DataFrame with the original DataFrame
# result_df = pd.concat([df, tfidf_df], axis=1)

# # Display the result
# display(result_df)

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# import pandas as pd

# # Assuming 'English_moviesdf' is your DataFrame with a 'tags' column
# # Replace 'English_moviesdf['tags']' with the actual column name from your DataFrame

# # Initialize TF-IDF Vectorizer
# tfidf = TfidfVectorizer()

# # Fit and transform the 'tags' column using TF-IDF
# tfidf_matrix = tfidf.fit_transform(english_movies_df['tags'])

# # Get feature names (words)
# feature_names = tfidf.get_feature_names_out()

# # Create a DataFrame to display TF-IDF values
# tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names )


# # Filter out columns with only zero TF-IDF values
# non_zero_tfidf_df = tfidf_df.loc[:, (tfidf_df != 0.0).any(axis=0)]

# # Show the DataFrame with non-zero TF-IDF values for each word in 'tags'
# display(non_zero_tfidf_df)
# # # Show the DataFrame with TF-IDF values for each word in 'tags'
# # display(tfidf_df)
